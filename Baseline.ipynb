# %% [markdown]
# ## Baseline Proposal
# - Vanilla BERT as our baseline
# - only consider the conversations, exlude prompts
# - Use Adam as our optimizer

# %% [markdown]
# ## Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/MyDrive/NYCU NLP Final/')

# %%
# !pip install transformers datasets > /dev/null
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
import numpy as np
import pandas as pd
import torch

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device(0)
torch.cuda.set_device(device)
print(f'{device} is now being set.')
# Out:
# cuda:0 is now being set.

# %%
# parameters
SEED = 42
N_SAMPLES_PER_LABEL = 377  # the smallest label count
MODEL_NAME='distilbert-base-uncased'
EPOCHS=50
TRAIN_BATCH_SIZE=16
VALID_BATCH_SIZE=64

# %%
import random

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# %% [markdown]
# ## Read data

# %%
traindf = pd.read_csv('data/new_train.csv')
validdf = pd.read_csv('data/new_valid.csv')
testdf = pd.read_csv('data/new_test.csv')

# %%
print(f'# train: {len(traindf)}')
print(f'# valid: {len(validdf)}')
print(f'# test: {len(testdf)}')
# Out:
# # train: 19533
# # valid: 2770
# # test: 2547

# %%
classes = traindf['label'].unique()
n_labels = len(classes)

# %%
# data selection: randomly select ${N_SAMPLES_PER_LABEL} samples for each label from training data
train_samples = []
for c in classes:
    samples = traindf[traindf['label'] == c]
    if len(samples) >= N_SAMPLES_PER_LABEL: 
        samples = samples.sample(N_SAMPLES_PER_LABEL, random_state=SEED)
    train_samples.append(samples)

traindf = pd.concat(train_samples)

# %%
len(traindf)
# Out:
# 12064

# %%
traindf[traindf['label'] == 17]
# Out:
#                    conv_id                                             prompt  \
# 19340  hit:9895_conv:19791                 the new printer at work is awful
# 6014    hit:2358_conv:4717  this tax war that us has started is borthering...
# 18859    hit:960_conv:1921  i was returning an item at a store and the per...
# 8497    hit:3813_conv:7626  i m waiting on my friend to confirm our plans ...
# 18870  hit:9619_conv:19239  came home the other day and my dogs were happy...
# ...                    ...                                                ...
# 5884    hit:2290_conv:4581  i was kind of bothered when i got passed over ...
# 8518    hit:3827_conv:7655                 when mosquitos are eating me alive
# 18938  hit:9668_conv:19336           my cat wont stop knocking over my plates
# 12352  hit:6003_conv:12007  it s election season and i keep getting roboca...
# 12191  hit:5920_conv:11840                                              i can
#
#                                                     conv  label     sent
# 19340  we got a new printer installed at work today [...     17  annoyed
# 6014   this tax war that us has started is borthering...     17  annoyed
# 18859  i was returning an item at a store and the per...     17  annoyed
# 8497   i m waiting on my friend to confirm our plans ...     17  annoyed
# 18870  so i came home yesterday and my lovely dogs gr...     17  annoyed
# ...                                                  ...    ...      ...
# 5884   i was pretty disappointed when i found out i w...     17  annoyed
# 8518   it finally rained today   and i know whats com...     17  annoyed
# 18938  my new cat wont stop knocking over the plates ...     17  annoyed
# 12352  man  these candidate robo calls are driving me...     17  annoyed
# 12191  i received a package yesterday and the content...     17  annoyed
#
# [377 rows x 5 columns]

# %%
validdf.loc[0, 'conv']
# Out:
# 'my upstairs neighbors make a ton of noise at all hours of the night  it makes it difficult for me to sleep   [SEP] that really sucks  maybe you should try egging their door  or just break in and pretend you re bigfoot while they re trying to sleep  [SEP] i m not trying to get arrested  i think i ll just wait things out until i move in two months  [SEP] i would go with the bigfoot option  you can get a costume on the cheap on ebay nowadays  i ve used that tactic countless times and it has never failed '

# %% [markdown]
# ## Tokenization & Dataset

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

train_enc = tokenizer(traindf['conv'].values.tolist(), truncation=True, padding=True)
valid_enc = tokenizer(validdf['conv'].values.tolist(), truncation=True, padding=True)
test_enc = tokenizer(testdf['conv'].values.tolist(), truncation=True, padding=True)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]

# %%
class NLPFinalDataset(torch.utils.data.Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels

    def __getitem__(self, idx):
        item = {k: torch.tensor(v[idx]) for k, v in self.features.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = NLPFinalDataset(train_enc, traindf['label'].values)
valid_dataset = NLPFinalDataset(valid_enc, validdf['label'].values)

# %% [markdown]
# ## Model Training

# %%
from datasets import load_metric

metric_acc = load_metric('accuracy')
metric_f1 = load_metric('f1')

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    acc = metric_acc.compute(predictions=predictions, references=labels)['accuracy']
    f1_score = metric_f1.compute(predictions=predictions, references=labels, average='macro')['f1']
    return {'accuracy': acc, 'F1': f1_score}
# Out:
# Downloading builder script:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.32k [00:00<?, ?B/s]

# %%
from transformers import AutoModelForSequenceClassification

# model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=n_labels)
model = AutoModelForSequenceClassification.from_pretrained('./baseline_trainer/checkpoint-17000')
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.weight', 'pre_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir='baseline_trainer',
    logging_dir='baseline_logs',
    logging_strategy='epoch',
    evaluation_strategy='epoch',
    num_train_epochs=EPOCHS,
    per_device_train_batch_size=TRAIN_BATCH_SIZE,
    per_device_eval_batch_size=VALID_BATCH_SIZE
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 12064
#   Num Epochs = 50
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 37700
#     <div>
#
#       <progress value='17053' max='37700' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [17053/37700 2:54:37 < 3:31:26, 1.63 it/s, Epoch 22.62/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.286500</td>
#       <td>1.782082</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.416600</td>
#       <td>1.680649</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.001800</td>
#       <td>1.778241</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.693400</td>
#       <td>1.899405</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.462800</td>
#       <td>2.179550</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.308600</td>
#       <td>2.396156</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.209300</td>
#       <td>2.705095</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.149000</td>
#       <td>3.166678</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.103900</td>
#       <td>3.399624</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.080800</td>
#       <td>3.676774</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.071700</td>
#       <td>3.944567</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.059200</td>
#       <td>4.320384</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.058300</td>
#       <td>4.459172</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.051200</td>
#       <td>4.784565</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.041500</td>
#       <td>4.748959</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.037500</td>
#       <td>4.882153</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.033800</td>
#       <td>5.027158</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.038600</td>
#       <td>5.235155</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.044400</td>
#       <td>5.208546</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.025900</td>
#       <td>5.452116</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.030700</td>
#       <td>5.500665</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.022200</td>
#       <td>5.538684</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to baseline_trainer/checkpoint-500
# Configuration saved in baseline_trainer/checkpoint-500/config.json
# Model weights saved in baseline_trainer/checkpoint-500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-1000
# Configuration saved in baseline_trainer/checkpoint-1000/config.json
# Model weights saved in baseline_trainer/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to baseline_trainer/checkpoint-1500
# Configuration saved in baseline_trainer/checkpoint-1500/config.json
# Model weights saved in baseline_trainer/checkpoint-1500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-2000
# Configuration saved in baseline_trainer/checkpoint-2000/config.json
# Model weights saved in baseline_trainer/checkpoint-2000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-2500
# Configuration saved in baseline_trainer/checkpoint-2500/config.json
# Model weights saved in baseline_trainer/checkpoint-2500/pytorch_model.bin
# Saving model checkpoint to baseline_trainer/checkpoint-3000
# Configuration saved in baseline_trainer/checkpoint-3000/config.json
# Model weights saved in baseline_trainer/checkpoint-3000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-3500
# Configuration saved in baseline_trainer/checkpoint-3500/config.json
# Model weights saved in baseline_trainer/checkpoint-3500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-4000
# Configuration saved in baseline_trainer/checkpoint-4000/config.json
# Model weights saved in baseline_trainer/checkpoint-4000/pytorch_model.bin
# Saving model checkpoint to baseline_trainer/checkpoint-4500
# Configuration saved in baseline_trainer/checkpoint-4500/config.json
# Model weights saved in baseline_trainer/checkpoint-4500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-5000
# Configuration saved in baseline_trainer/checkpoint-5000/config.json
# Model weights saved in baseline_trainer/checkpoint-5000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-5500
# Configuration saved in baseline_trainer/checkpoint-5500/config.json
# Model weights saved in baseline_trainer/checkpoint-5500/pytorch_model.bin
# Saving model checkpoint to baseline_trainer/checkpoint-6000
# Configuration saved in baseline_trainer/checkpoint-6000/config.json
# Model weights saved in baseline_trainer/checkpoint-6000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-6500
# Configuration saved in baseline_trainer/checkpoint-6500/config.json
# Model weights saved in baseline_trainer/checkpoint-6500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-7000
# Configuration saved in baseline_trainer/checkpoint-7000/config.json
# Model weights saved in baseline_trainer/checkpoint-7000/pytorch_model.bin
# Saving model checkpoint to baseline_trainer/checkpoint-7500
# Configuration saved in baseline_trainer/checkpoint-7500/config.json
# Model weights saved in baseline_trainer/checkpoint-7500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-8000
# Configuration saved in baseline_trainer/checkpoint-8000/config.json
# Model weights saved in baseline_trainer/checkpoint-8000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-8500
# Configuration saved in baseline_trainer/checkpoint-8500/config.json
# Model weights saved in baseline_trainer/checkpoint-8500/pytorch_model.bin
# Saving model checkpoint to baseline_trainer/checkpoint-9000
# Configuration saved in baseline_trainer/checkpoint-9000/config.json
# Model weights saved in baseline_trainer/checkpoint-9000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-9500
# Configuration saved in baseline_trainer/checkpoint-9500/config.json
# Model weights saved in baseline_trainer/checkpoint-9500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-10000
# Configuration saved in baseline_trainer/checkpoint-10000/config.json
# Model weights saved in baseline_trainer/checkpoint-10000/pytorch_model.bin
# Saving model checkpoint to baseline_trainer/checkpoint-10500
# Configuration saved in baseline_trainer/checkpoint-10500/config.json
# Model weights saved in baseline_trainer/checkpoint-10500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-11000
# Configuration saved in baseline_trainer/checkpoint-11000/config.json
# Model weights saved in baseline_trainer/checkpoint-11000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-11500
# Configuration saved in baseline_trainer/checkpoint-11500/config.json
# Model weights saved in baseline_trainer/checkpoint-11500/pytorch_model.bin
# Saving model checkpoint to baseline_trainer/checkpoint-12000
# Configuration saved in baseline_trainer/checkpoint-12000/config.json
# Model weights saved in baseline_trainer/checkpoint-12000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-12500
# Configuration saved in baseline_trainer/checkpoint-12500/config.json
# Model weights saved in baseline_trainer/checkpoint-12500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-13000
# Configuration saved in baseline_trainer/checkpoint-13000/config.json
# Model weights saved in baseline_trainer/checkpoint-13000/pytorch_model.bin
# Saving model checkpoint to baseline_trainer/checkpoint-13500
# Configuration saved in baseline_trainer/checkpoint-13500/config.json
# Model weights saved in baseline_trainer/checkpoint-13500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-14000
# Configuration saved in baseline_trainer/checkpoint-14000/config.json
# Model weights saved in baseline_trainer/checkpoint-14000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-14500
# Configuration saved in baseline_trainer/checkpoint-14500/config.json
# Model weights saved in baseline_trainer/checkpoint-14500/pytorch_model.bin
# Saving model checkpoint to baseline_trainer/checkpoint-15000
# Configuration saved in baseline_trainer/checkpoint-15000/config.json
# Model weights saved in baseline_trainer/checkpoint-15000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-15500
# Configuration saved in baseline_trainer/checkpoint-15500/config.json
# Model weights saved in baseline_trainer/checkpoint-15500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-16000
# Configuration saved in baseline_trainer/checkpoint-16000/config.json
# Model weights saved in baseline_trainer/checkpoint-16000/pytorch_model.bin
# Saving model checkpoint to baseline_trainer/checkpoint-16500
# Configuration saved in baseline_trainer/checkpoint-16500/config.json
# Model weights saved in baseline_trainer/checkpoint-16500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 2770
#   Batch size = 64
# Saving model checkpoint to baseline_trainer/checkpoint-17000
# Configuration saved in baseline_trainer/checkpoint-17000/config.json
# Model weights saved in baseline_trainer/checkpoint-17000/pytorch_model.bin

# %% [markdown]
# ## Prediction & Evaluation

# %%
eval_pred = trainer.predict(train_dataset)
# Out:
# ***** Running Prediction *****
#   Num examples = 12064
#   Batch size = 64
#     <div>
#
#       <progress value='189' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [189/189 05:09]
#     </div>

# %%
compute_metrics((eval_pred.predictions, eval_pred.label_ids))
# Out:
# {'F1': 0.998504962019102, 'accuracy': 0.9985079575596817}

# %%
eval_pred = trainer.predict(valid_dataset)
# Out:
# ***** Running Prediction *****
#   Num examples = 2770
#   Batch size = 64
#     <div>
#
#       <progress value='240' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [189/189 06:33]
#     </div>

# %%
compute_metrics((eval_pred.predictions, eval_pred.label_ids))
# Out:
# {'F1': 0.4889328143906021, 'accuracy': 0.4967509025270758}

# %% [markdown]
# ## Master Proposal
# - Use BERT to infer `prompt` & `utterance` representations，concatenate the two hypotheses.
# - Add a `LayerNorm` layer to receive the concatenated result.
# - Use `Linear` layer to do classification.
# - Maybe we can use `SAM` to smooth the loss landscape
